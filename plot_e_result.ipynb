# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# e = np.loadtxt('e/e_galsim_deltaPix=0.20.txt')
e = np.loadtxt('e/high_res')
# e = np.loadtxt('e/t')
theta_E = 0.42            # unit: arcsec
num_pix = 30
num = 30
x = y = np.linspace(-theta_E*1.2, theta_E*1.2, num)
xx, yy = np.meshgrid(x, y)
plt.imshow(e)
plt.colorbar()
plt.show()

# %%
# e = np.loadtxt('e/e_galsim_deltaPix=0.20.txt')
e = np.loadtxt('e/high_res_2')
# e = np.loadtxt('e/t')
theta_E = 0.42            # unit: arcsec
num_pix = 30
num = 30
x = y = np.linspace(-theta_E*1.2, theta_E*1.2, num)
xx, yy = np.meshgrid(x, y)
plt.imshow(e)
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, e)

# %%
e, err = np.loadtxt('./e-r/high_res').T
plt.errorbar(np.linspace(0, 0.7, 30), e, err)
# Out:
# <ErrorbarContainer object of 3 artists>
