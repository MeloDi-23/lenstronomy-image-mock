# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# e = np.loadtxt('e/e_galsim_deltaPix=0.20.txt')
e = np.loadtxt('e/high_res_mean')
# e = np.loadtxt('e/t')
theta_E = 0.42            # unit: arcsec
num_pix = 30
num = 30
x = y = np.linspace(-theta_E*1.2, theta_E*1.2, num)
xx, yy = np.meshgrid(x, y)
plt.imshow(e)

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, e)

# %% [markdown]
#  --d_l 4000 --d_s 8000 --deltaPix 0.1 --fwhm 0.35

# %%
e, err = np.loadtxt('./e-r/high_res_mean_2')
plt.errorbar(np.linspace(0, 1, len(e)), e, err)
# Out:
# <ErrorbarContainer object of 3 artists>
